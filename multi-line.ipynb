# %%
import pandas as pd
import plotly.graph_objects as go
import datetime

days_df = pd.read_csv(r"Z:\Dev\plotly-charts\health_data\days_data.csv")
weather_df = pd.read_csv(r"Z:\Dev\plotly-charts\health_data\weather_data.csv")

days_df['Day'] = pd.to_datetime(days_df['Date']).dt.normalize() + datetime.timedelta(hours=12)
weather_df['Day'] = pd.to_datetime(weather_df['Date']).dt.normalize() + datetime.timedelta(hours=12)

# %%
fig = go.Figure()

fig.add_trace(go.Scatter(x=days_df["Day"], y=days_df["Calories In"], name='Calories Eaten',
                         line=dict(color='firebrick', width=4)))
fig.add_trace(go.Scatter(x=days_df["Day"], y=days_df["Exercise Duration"], name = 'Exercise Time (seconds)',
                         line=dict(color='orange', width=4, dash='dot')))
fig.add_trace(go.Scatter(x=days_df["Day"], y=days_df["Exercise Calories"], name = 'Exercise Calories',
                         line=dict(color='royalblue', width=4)))
fig.add_trace(go.Scatter(x=days_df["Day"], y=weather_df["High"] * 100, name = 'High Temp (multiplied by 100)',
                         line=dict(color='green', width=4, dash='dash')))
fig.add_trace(go.Scatter(x=days_df["Day"], y=days_df["Whiskies"] * 1000 + days_df["Beers"] * 1000, name = 'Total Drinks (multiplied by 1000)',
                         line=dict(color='purple', width=4)))


weekends = ["2020-03-27,2020-03-30","2020-04-04,2020-04-06","2020-04-10,2020-04-13",
           "2020-04-18,2020-04-20"]

dicts = []

def getDicts(start, end):
    wknd = dict(
                type="rect",
                xref="x",
                yref="paper",
                x0=start,
                y0=0,
                x1=end,
                y1=1,
                fillcolor="lightgray",
                opacity=0.5,
                layer="below",
                line_width=0,
            )
    dicts.append(wknd)

for w in weekends:
    s = w.split(",")[0]
    e = w.split(",")[1]
    getDicts(s, e)
    
fig.update_layout(
    paper_bgcolor='rgba(0,0,0,0)',
    plot_bgcolor='rgba(0,0,0,0)',
    shapes=dicts
)
fig.write_html(r"Z:\Dev\plotly-charts\index.html")
fig.show()
# Out:
# <div>
#
#
#             <div id="a66f2e8d-aee4-42de-b62f-4e3bd65c6131" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("a66f2e8d-aee4-42de-b62f-4e3bd65c6131")) {
#                     Plotly.newPlot(
#                         'a66f2e8d-aee4-42de-b62f-4e3bd65c6131',
# ...

# %%
fig = go.Figure()

fig.add_trace(go.Scatter(x=days_df["Day"], y=days_df["Whiskies"] + days_df["Beers"], name = 'Total Drinks',
                         line=dict(color='purple', width=4)))
fig.add_trace(go.Scatter(x=days_df["Day"], y=days_df["Whiskies"], name = 'Whiskies',
                         line=dict(color='orange', width=4)))
fig.add_trace(go.Scatter(x=days_df["Day"], y=days_df["Beers"], name='Beers',
                         line=dict(color='black', width=4)))

dicts = []

def getDicts(start, end):
    wknd = dict(
                type="rect",
                xref="x",
                yref="paper",
                x0=start,
                y0=0,
                x1=end,
                y1=1,
                fillcolor="lightgray",
                opacity=0.5,
                layer="below",
                line_width=0,
            )
    dicts.append(wknd)

for w in weekends:
    s = w.split(",")[0]
    e = w.split(",")[1]
    getDicts(s, e)
    
fig.update_layout(
    paper_bgcolor='rgba(0,0,0,0)',
    plot_bgcolor='rgba(0,0,0,0)',
    shapes=dicts
)


fig.show()
# Out:
# <div>
#
#
#             <div id="86dab56e-1487-4985-8ff7-13c822aff2bf" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("86dab56e-1487-4985-8ff7-13c822aff2bf")) {
#                     Plotly.newPlot(
#                         '86dab56e-1487-4985-8ff7-13c822aff2bf',
# ...
